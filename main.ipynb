# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import duckdb as db
from datasets import load_dataset
from dotenv import load_dotenv

# %%
# %matplotlib inline

# %%
# 1. Load the hidden variables from your .env file
load_dotenv()

# 2. Grab the token securely
my_token = os.getenv("HF_TOKEN")

# 3. Pass the token into the load_dataset function
dataset = load_dataset(
    "foursquare/fsq-os-places",
    split="train",
    token=my_token
)
# Out:
# Resolving data files:   0%|          | 0/100 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/100 [00:00<?, ?files/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/118M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/118M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/126M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/99.1M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/131M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/124M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/119M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/119M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/119M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/111M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/111M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/121M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/112M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/115M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/127M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/111M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/109M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/106M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/110M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/106M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/121M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/103M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/121M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/135M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/99.7M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/102M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/109M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/113M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/99.2M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/112M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/95.5M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/98.9M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/96.9M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/99.8M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/84.6M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/97.5M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/94.2M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/102M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/106M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/109M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/98.3M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/107M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/100M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/110M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/115M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/111M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/110M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/118M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/103M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/109M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/102M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/102M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/112M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/118M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/107M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/122M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/111M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/131M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/115M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/120M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/133M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/128M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/126M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/129M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/123M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/112M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/116M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/124M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/123M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/138M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/131M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/123M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/132M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/122M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/108M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/106M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/106M [00:00<?, ?B/s]
# release/dt=2026-04-14/places/parquet/pla(…):   0%|          | 0.00/114M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/107502541 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/90 [00:00<?, ?it/s]

# %%
# Export the entire dataset straight to a local Parquet file
dataset.to_parquet("all_foursquare_locations.parquet")
# Out:
# Creating parquet from Arrow format:   0%|          | 0/474 [00:00<?, ?ba/s]
# 47312790141

# %%
# Query the entire global dataset
sql_query = """
    SELECT * FROM 'all_foursquare_locations.parquet'
    WHERE country = 'AU' AND name IS NOT NULL;
"""

results = db.query(sql_query).df()

# %%
# Save the filtered Australian locations to a compressed Parquet file
results.to_parquet('au_locations.parquet', index=False)

# %%
# Query the entire global dataset
sql_query = """
    SELECT * FROM 'au_locations.parquet'
"""

aus_results = db.query(sql_query).df()
display(aus_results)
# Out:
#                      fsq_place_id                             name   latitude  \
# 0        1b40c173e7df4542e6463972           Nailtazia Nails Beauty        NaN
# 1        61deb6eb689f42f9d51f6b07                            Regus        NaN
# 2        d7d95192e0644778a9ac59f3  Miss Maud Swedish Pastry Houses        NaN
# 3        23f2f428dd524faaf9105862         Outdoor Furniture Online        NaN
# 4        384ca2f380104d63fdf71808          AF Antique Restorations        NaN
# ...                           ...                              ...        ...
# 1496347  62e5c5cd76f8674ce51f906c                            Jetty -31.523158
# 1496348  66ad8ddeef359c27907b27c7               Benny’s Fish Truck -31.523349
# 1496349  50467450e4b05e30e88e28eb                      Mount Eliza -31.513594
# 1496350  4ce22acd3644a0933e12619f                      North Beach -31.517629
# 1496351  56bd7ccc498e7eda53aa980d                   Ball's Pyramid -31.754372
#
#           longitude                                            address  \
# 0               NaN          Unit 5 Cnr Vansittart Rd & Mt Lindsay Hwy
# 1               NaN                                40 City Rd Level 23
# 2               NaN  Great Eastern Hwy, Midland Gate Shopping Centr...
# 3               NaN                              11 Villiers Dr Unit 4
# 4               NaN                                  100 Canterbury Rd
# ...             ...                                                ...
# 1496347  159.058579                                                NaN
# 1496348  159.058850                                                NaN
# 1496349  159.040227                                                NaN
# 1496350  159.043549                                                NaN
# 1496351  159.251568                                                NaN
#
#                  locality            region postcode  admin_region  post_town  \
# 0            Regents Park               QLD     4118          <NA>       <NA>
# 1               Melbourne               VIC     3006          <NA>       <NA>
# 2                 Midland                WA     6056          <NA>       <NA>
# 3               Currumbin               QLD     4223          <NA>       <NA>
# 4              Camberwell               VIC     3126          <NA>       <NA>
# ...                   ...               ...      ...           ...        ...
# 1496347  Lord Howe Island               NSW     2898          <NA>       <NA>
# 1496348  Lord Howe Island               NSW     2898          <NA>       <NA>
# 1496349  Lord Howe Island               NSW     2898          <NA>       <NA>
# 1496350  Lord Howe Island               NSW     2898          <NA>       <NA>
# 1496351  Lord Howe Island  Lord Howe Island     2898          <NA>       <NA>
#
#          ... email facebook_id instagram twitter  \
# 0        ...   NaN        <NA>       NaN     NaN
# 1        ...   NaN        <NA>       NaN     NaN
# 2        ...   NaN        <NA>       NaN     NaN
# 3        ...   NaN        <NA>       NaN     NaN
# 4        ...   NaN        <NA>       NaN     NaN
# ...      ...   ...         ...       ...     ...
# 1496347  ...   NaN        <NA>       NaN     NaN
# 1496348  ...   NaN        <NA>       NaN     NaN
# 1496349  ...   NaN        <NA>       NaN     NaN
# 1496350  ...   NaN        <NA>       NaN     NaN
# 1496351  ...   NaN        <NA>       NaN     NaN
#
#                                           fsq_category_ids  \
# 0                               [54541900498ea6ccd0202697]
# 1                               [4bf58dd8d48988d174941735]
# 2                               [4bf58dd8d48988d16d941735]
# 3                               [4bf58dd8d48988d1f8941735]
# 4                                                     <NA>
# ...                                                    ...
# 1496347  [4e74f6cabd41c4836eac4c31, 4bf58dd8d48988d12d9...
# 1496348                         [4edd64a0c7ddd24ca188df1a]
# 1496349                         [4eb1d4d54b900d56c88a45fc]
# 1496350                         [4bf58dd8d48988d1e2941735]
# 1496351                         [50aaa4314b90af0d42d5de10]
#
#                                        fsq_category_labels  \
# 0        [Business and Professional Services > Health a...
# 1        [Business and Professional Services > Office >...
# 2        [Dining and Drinking > Cafe, Coffee, and Tea H...
# 3                      [Retail > Furniture and Home Store]
# 4                                                     <NA>
# ...                                                    ...
# 1496347  [Travel and Transportation > Pier, Travel and ...
# 1496348  [Dining and Drinking > Restaurant > Fish and C...
# 1496349                [Landmarks and Outdoors > Mountain]
# 1496350                   [Landmarks and Outdoors > Beach]
# 1496351                  [Landmarks and Outdoors > Island]
#
#                                             placemaker_url unresolved_flags  \
# 0        https://foursquare.com/placemakers/review-plac...             <NA>
# 1        https://foursquare.com/placemakers/review-plac...             <NA>
# 2        https://foursquare.com/placemakers/review-plac...             <NA>
# 3        https://foursquare.com/placemakers/review-plac...             <NA>
# 4        https://foursquare.com/placemakers/review-plac...             <NA>
# ...                                                    ...              ...
# 1496347  https://foursquare.com/placemakers/review-plac...             <NA>
# 1496348  https://foursquare.com/placemakers/review-plac...             <NA>
# 1496349  https://foursquare.com/placemakers/review-plac...             <NA>
# 1496350  https://foursquare.com/placemakers/review-plac...             <NA>
# 1496351  https://foursquare.com/placemakers/review-plac...             <NA>
#
#                                                       geom  \
# 0                                                     <NA>
# 1                                                     <NA>
# 2                                                     <NA>
# 3                                                     <NA>
# 4                                                     <NA>
# ...                                                    ...
# 1496347  [0, 0, 0, 0, 1, 64, 99, 225, 223, 224, 136, 23...
# 1496348  [0, 0, 0, 0, 1, 64, 99, 225, 226, 25, 101, 43,...
# 1496349  [0, 0, 0, 0, 1, 64, 99, 225, 73, 138, 20, 254,...
# 1496350  [0, 0, 0, 0, 1, 64, 99, 225, 100, 193, 0, 189,...
# 1496351  [0, 0, 0, 0, 1, 64, 99, 232, 12, 217, 0, 0, 0,...
#
#                                                       bbox
# 0                                                     <NA>
# 1                                                     <NA>
# 2                                                     <NA>
# 3                                                     <NA>
# 4                                                     <NA>
# ...                                                    ...
# 1496347  {'xmax': 159.0585787462518, 'xmin': 159.058578...
# 1496348  {'xmax': 159.05885, 'xmin': 159.05885, 'ymax':...
# 1496349  {'xmax': 159.04022697544735, 'xmin': 159.04022...
# 1496350  {'xmax': 159.04354906219976, 'xmin': 159.04354...
# 1496351  {'xmax': 159.25156831741333, 'xmin': 159.25156...
#
# [1496352 rows x 27 columns]
